# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt


#NAME- ADITYA ANANAT AUNDHEKAR
#ROLL NO-13
#DIV-A



img = cv2.imread(r"C:\Users\adity\Desktop\mini soft\horse.png")
plt.imshow(img)
plt.title("Original Image")
img1 = ~img
plt.imshow(img1)
plt.title("Negative of Original Image")
# Out:
# Text(0.5, 1.0, 'Negative of Original Image')
